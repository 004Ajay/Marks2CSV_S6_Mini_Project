# %%
from PIL import Image

# %%
im = Image.open("D:/AJAYMON/AJAY/Programming/S6_Mini_Project/dataset/numbers/5/Five_full (101).jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=90x140>

# %%
im.resize((40, 40), resample=Image.BILINEAR)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_32880\3377670269.py:1: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   im.resize((40, 40), resample=Image.BILINEAR)
# <PIL.Image.Image image mode=RGB size=40x40>

# %%
im.size
# Out:
# (90, 140)
