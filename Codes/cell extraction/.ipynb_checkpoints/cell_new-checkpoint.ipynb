# %%
from img2table.document import Image
from img2table.ocr import PaddleOCR
import pandas as pd
import numpy as np
import cv2
from pdf2image import convert_from_path
import matplotlib.pyplot as plt
from PIL import Image as PIL_Image, ImageDraw

# %%
images = convert_from_path("D:/github/S6_Mini_Project/Codes/cell extraction/new_exm.pdf")
# change or give PDF name here....................new_exm.pdf

# %%
# Cropping & Saving the cropped image to folder

for i in range(len(images)):
    img = images[i].convert('L') # convert('L') for gray scaling
    _, height = img.size
    cropped_img = img.crop((150, height / 2 + 50, 1600, height - 300)) # left, top, right, bottom
    cropped_img.save(f"D:/github/S6_Mini_Project/Codes/cell extraction/cropped_temp/cropped_ima{i}.jpg")

# %%
# Getting the crooped image & extracting cell from it

a=0
for i in range(len(images)):
    ## Image opening & performing OCR
    paddle_ocr = PaddleOCR(lang="en")
    src = f"D:/github/S6_Mini_Project/Codes/cell extraction/cropped_temp/cropped_ima{i}.jpg"

    doc = Image(src, dpi=200)
    extracted_tables = doc.extract_tables(implicit_rows=True, min_confidence=50)

    img = PIL_Image.open(src) # opening image for cell croppping
    
    for table in extracted_tables:
        for row in table.content.values():
            for cell in row:
                crp = img.crop((cell.bbox.x1, cell.bbox.y1, cell.bbox.x2, cell.bbox.y2))
                crp = crp.resize((40, 40)) # change the size of cell image output here
                crp.save(f"D:/github/S6_Mini_Project/Codes/cell extraction/temp/ima{a}.jpg")
                a+=1

# %%
type(doc)
# Out:
# img2table.document.image.Image

# %%
type(cropped_img)
# Out:
# PIL.Image.Image

# %%
doc
# Out:
# Image(src='D:/github/S6_Mini_Project/Codes/cell extraction/cropped_temp/cropped_ima6.jpg', dpi=200, detect_rotation=False)

# %%
cropped_img
# Out:
# <PIL.Image.Image image mode=L size=1450x734>

# %%
from PIL import Image
import img2html
gcc=img2html.img_to_table(cropped_img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [32], line 2
#       1 from PIL import Image
# ----> 2 gcc=Image.open(cropped_img)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3101, in open(fp, mode, formats)
#    3098     fp = io.BytesIO(fp.read())
#    3099     exclusive_fp = True
# -> 3101 prefix = fp.read(16)
#    3103 preinit()
#    3105 accept_warnings = []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:517, in Image.__getattr__(self, name)
#     515     deprecate("Image categories", 10, "is_animated", plural=True)
#     516     return self._category
# --> 517 raise AttributeError(name)
#
# AttributeError: read
