# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image as PIL_Image, ImageDraw

# %%
image = cv2.imread('adarsh.jpg')
height, width, _ = image.shape
# print(image.shape)
img_lowerHalf = image[height//2+100:, 100:-100]
plt.figure(figsize=(10, 10))
plt.imshow(img_lowerHalf)
plt.show()

# %%
img_lowerHalf
# Out:
# array([[[190, 178, 176],
#         [189, 177, 175],
#         [189, 177, 175],
#         ...,
#         [188, 178, 178],
#         [189, 179, 179],
#         [189, 179, 179]],
#
#        [[190, 178, 176],
#         [189, 177, 175],
#         [189, 177, 175],
#         ...,
#         [188, 178, 178],
#         [189, 179, 179],
#         [189, 179, 179]],
#
#        [[190, 178, 176],
#         [189, 177, 175],
#         [189, 177, 175],
#         ...,
#         [188, 178, 178],
#         [189, 179, 179],
#         [189, 179, 179]],
#
#        ...,
#
#        [[193, 179, 173],
#         [193, 179, 173],
#         [193, 179, 173],
#         ...,
#         [197, 180, 177],
#         [197, 180, 177],
#         [197, 180, 177]],
#
#        [[190, 176, 170],
#         [190, 176, 170],
#         [189, 175, 169],
#         ...,
#         [202, 183, 180],
#         [200, 181, 178],
#         [200, 181, 178]],
#
#        [[191, 177, 171],
#         [190, 176, 170],
#         [190, 176, 170],
# ...

# %%
imgg = Image.fromarray(img_lowerHalf)

# Load the image using PIL
img = PIL_Image.open(imgg)

# Create a draw object
draw = ImageDraw.Draw(img)

plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [20], line 4
#       1 imgg = Image.fromarray(img_lowerHalf)
#       3 # Load the image using PIL
# ----> 4 img = PIL_Image.open(imgg)
#       6 # Create a draw object
#       7 draw = ImageDraw.Draw(img)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:3140, in open(fp, mode, formats)
#    3137     fp = io.BytesIO(fp.read())
#    3138     exclusive_fp = True
# -> 3140 prefix = fp.read(16)
#    3142 preinit()
#    3144 accept_warnings = []
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\PIL\Image.py:517, in Image.__getattr__(self, name)
#     515     deprecate("Image categories", 10, "is_animated", plural=True)
#     516     return self._category
# --> 517 raise AttributeError(name)
#
# AttributeError: read

# %%
import numpy as np
from PIL import Image

# Create a numpy ndarray with random pixel values
width = 200
height = 100
channels = 1
arr = np.random.randint(0, 255, size=(height, width), dtype=np.uint8)

# Convert the ndarray to an image
img = Image.fromarray(arr)

# Show the image in a window
plt.imshow(img)
plt.show()
